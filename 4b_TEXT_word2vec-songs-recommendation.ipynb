# %% [markdown]
# # PRACTICA 4b - CARLOS ARRANZ HERRERO
# ## PARTE 1 - El objetivo es usar el modelo word2vec para encontrar canciones similares utilizando un corpus en español

# %%
import pandas as pd
import numpy as np
import gensim.models.word2vec as w2v
import multiprocessing
import os
import re
import pprint
import sklearn.manifold
import matplotlib.pyplot as plt
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %% [markdown]
# 1. Cargamos el csv con las canciones en español

# %%
songs = pd.read_csv("hhgroups_merge_28_05.csv", header=0)
#songs.head()
songs.head(10)
# Out:
#    id           artista                                            cancion  \
# 0   0             Denom             Machete (con Jarfaiter y Gente jodida)
# 1   1             Denom                           Vacío (con Ivo Incuerdo)
# 2   2             Denom  El orgullo es fiel (con Juancho Marqués y Elio...
# 3   3             Denom                    Mueve mueve (con Fernandocosta)
# 4   4  Jaro Desperdizio                                           Insomnia
# 5   5              Khan                                               Lobo
# 6   6               Dyo                   Claridad [Productor desconocido]
# 7   7         Sheldrack                            Especial agradecimiento
# 8   8              Arce                              Huella (con Pitizion)
# 9   9              Arce                                              Boxer
#
#                            album  \
# 0                       Medicina
# 1                       Medicina
# 2                       Medicina
# 3                       Medicina
# 4  Sin álbum, es un vídeo suelto
# 5  Sin álbum, es un vídeo suelto
# 6   Sin álbum, es un tema suelto
# 7                     Titiritero
# 8                        Pedigrí
# 9                        Pedigrí
#
#                                                letra  anyo  visitas
# 0  Para su nuevo disco "Medicina", Denom ha vuelt...  2019      126
# 1  [Denom]\nYo que quería, yo que pedía vida,\nSe...  2019      361
# 2  "El orgullo es fiel" es uno de los cortes incl...  2019      262
# 3  [Estribillo: Denom] (x2)\nMueve, mueve, mueve,...  2019      578
# 4  [Estribillo]\nY en esta noche, ¿Quién me arrop...  2019      219
# 5  Que nadie creía en leyends hasta que llegué yo...  2019      683
# 6  Me olvidé tomarme la pastilla otra vez,\nEstar...  2019       58
# 7  Hace tiempo dejé de buscar el sentido de la vi...  2018       35
# 8  [Estribillo: Pitizon]\nNo te voy a negar que a...  2019      119
# 9  Se preguntaron dónde está, me perdí como Wally...  2019      843

# %% [markdown]
# 2. Cargamos la biblia como corpus

# %%
with open("biblia.txt", "r") as f:
    data = f.readlines()

biblia = ""
for i in data:
    biblia = biblia + i
corpus_biblia = biblia.split("\n")
corpus_biblia[1:20]
# Out:
# ['',
#  'Parte # 1 (INCLUYE LA LEY), los 10 primeros libros del AT: Gn, Ex, Lv, Nm, Dt, Jos, Jue, Rt, 1 S y 2 S',
#  '',
#  '',
#  'LIBRO PRIMERO DE MOISÉS',
#  '',
#  'GÉNESIS',
#  '',
#  'La creación',
#  '',
#  'Génesis 1',
#  '',
#  'Génesis 1:1',
#  '          En el principio creó Dios los cielos y la tierra.',
#  '',
#  ' Génesis 1:2',
#  '          Y la tierra estaba desordenada y vacía, y las tinieblas',
#  '          estaban sobre la faz del abismo, y el Espíritu de Dios se',
#  '          movía sobre la faz de las aguas.']

# %% [markdown]
# ## Construimos el vocabulario primero con el corpus de la biblia y luego con las canciones

# %%
corpus_biblia = []
 
for line in data:
    words = line.lower().split()
    corpus_biblia.append(words)

text_corpus = []
# for song in songs['text']: # ENGLISH
for song in songs['letra']: # SPANISH
    words = song.lower().split()
    text_corpus.append(words)


    # Dimensionality of the resulting word vectors.
# more dimensions, more computationally expensive to train
# but also more accurate
# more dimensions = more generalized
# num_features = 50
num_features = 100

# Minimum word count threshold.
min_word_count = 1

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 9

downsampling = 1e-1

# Seed for the RNG, to make the results reproducible.
# random number generator
# deterministic, good for debugging
seed = 1

songs2vec_biblia = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

songs2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

songs2vec_biblia.build_vocab(corpus_biblia)
songs2vec.build_vocab(text_corpus)

print ("corpus de la biblia: ",len(corpus_biblia))
print ("corpus de las canciones: ",len(text_corpus))
# Out:
# corpus de la biblia:  35186
# corpus de las canciones:  9325

# %% [markdown]
# ## ENTRENAMOS EL MODELO CON LAS CANCIONES

# %%
import time

# CANCIONES
start_time = time.time()

songs2vec.train(text_corpus, total_examples=songs2vec.corpus_count, epochs=10)

if not os.path.exists("trained"):
    os.makedirs("trained")

songs2vec.save(os.path.join("trained", "songs2vec.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 91.6035692691803 seconds ---

# %% [markdown]
# ## ENTRENAMOS EL MODELO CON LA BIBLIA

# %%
# BIBLIA
start_time = time.time()

songs2vec_biblia.train(corpus_biblia, total_examples=songs2vec_biblia.corpus_count, epochs=10)

if not os.path.exists("trained"):
    os.makedirs("trained")

songs2vec_biblia.save(os.path.join("trained", "songs2vec_biblia.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 12.900712728500366 seconds ---

# %%
songs2vec = w2v.Word2Vec.load(os.path.join("trained", "songs2vec.w2v"))
songs2vec_biblia = w2v.Word2Vec.load(os.path.join("trained", "songs2vec_biblia.w2v"))

# %% [markdown]
# ### Let's explore our model

# %% [markdown]
# #### Como estamos analizando palabras de canciones, es probable que salgan palabras quie rimen entre ellas "amor", "rencor", "dolor", y además tienen que ver

# %% [markdown]
# ### CORPUS CANCIONES

# %%
songs2vec.wv.most_similar("amor")
# Out:
# [('amor,', 0.8003445863723755),
#  ('platónico,', 0.7525262832641602),
#  ('dolor', 0.7465886473655701),
#  ('platónico...', 0.7451823949813843),
#  ('platónico', 0.7396997213363647),
#  ('odio,', 0.735668957233429),
#  ('fónicos,', 0.7285569310188293),
#  ('rencor,', 0.71053147315979),
#  ('odio', 0.697514533996582),
#  ('¿amor', 0.6955718398094177)]

# %%
songs2vec.wv.most_similar("muerte")
# Out:
# [('muerte,', 0.7952715158462524),
#  ('suerte', 0.7297278642654419),
#  ('vencida.', 0.7029434442520142),
#  ('decidirá', 0.6993062496185303),
#  ('dolorosa', 0.6943186521530151),
#  ('dolorosa,', 0.6892216205596924),
#  ('bebere', 0.6889551877975464),
#  ('separe.', 0.6842770576477051),
#  ('lenta.', 0.6833838224411011),
#  ('incumplida,', 0.6825197339057922)]

# %%
songs2vec.wv.most_similar("vida")
# Out:
# [('vida,', 0.7875282764434814),
#  ('complicada,', 0.6742469668388367),
#  ('vida.', 0.6729293465614319),
#  ('vida....', 0.6709336042404175),
#  ('láminas,', 0.6671640872955322),
#  ('muerte', 0.6626427173614502),
#  ('saberla', 0.6601601839065552),
#  ('semo', 0.6598530411720276),
#  ('corta.', 0.659111499786377),
#  ('divertida,', 0.6589784026145935)]

# %%
songs2vec.wv.most_similar("quiero")
# Out:
# [('puedo', 0.7458089590072632),
#  ('escaparme,', 0.706802487373352),
#  ('mí)', 0.6960821747779846),
#  ('quiero,', 0.6954433917999268),
#  ('viajar,', 0.6893172264099121),
#  ('prefiero', 0.68848717212677),
#  ('oirte,', 0.6872514486312866),
#  ('besarte,', 0.6827871799468994),
#  ('centrarme,', 0.6806821823120117),
#  ('migre,', 0.6772598028182983)]

# %%
songs2vec.wv.most_similar(positive=['dinero'])
# Out:
# [('dinero,', 0.7281863689422607),
#  ('¡money!', 0.695968747138977),
#  ('ingresa', 0.6924116015434265),
#  ('gastándose', 0.6904134750366211),
#  ('innecesario,', 0.689932107925415),
#  ('cobre.', 0.6898140907287598),
#  ('parné,', 0.682694673538208),
#  ('pasta', 0.6821595430374146),
#  ('shitto,', 0.6790845990180969),
#  ('rico', 0.6759052872657776)]

# %%
songs2vec.wv.most_similar(negative=['dinero'], positive=["te","quiero","vente"])
# Out:
# [('escucharme,', 0.6686912775039673),
#  ('"egotripping"', 0.6678745746612549),
#  ('consigues', 0.6581234931945801),
#  ('triste!...', 0.6580321788787842),
#  ('babe,', 0.6574562191963196),
#  ('selmouni]', 0.653918981552124),
#  ('fuiste)', 0.6535998582839966),
#  ('decir;', 0.6508377194404602),
#  ('túmbate,', 0.6506816148757935),
#  ('despiertes,', 0.6490801572799683)]

# %% [markdown]
# ### CORPUS BIBLIA

# %%
songs2vec_biblia.wv.most_similar("amor")
# Out:
# [('amor,', 0.7578495740890503),
#  ('tito,', 0.7438755035400391),
#  ('cristo;', 0.7399457693099976),
#  ('ministro', 0.7332652807235718),
#  ('creyentes', 0.7306680083274841),
#  ('porque:', 0.7295238971710205),
#  ('entrañable', 0.7286202311515808),
#  ('justificados', 0.7276186943054199),
#  ('epafras,', 0.7276151180267334),
#  ('mansedumbre,', 0.7254500389099121)]

# %%
songs2vec_biblia.wv.most_similar("muerte")
# Out:
# [('digna', 0.7293793559074402),
#  ('condenación,', 0.7277209758758545),
#  ('justificados', 0.7143285870552063),
#  ('transgresión', 0.7132445573806763),
#  ('muerte.', 0.7062108516693115),
#  ('condenado', 0.7044743895530701),
#  ('persecución', 0.6962323188781738),
#  ('fuésemos', 0.6957705020904541),
#  ('fe.', 0.6936288475990295),
#  ('haberlo', 0.691423773765564)]

# %%
songs2vec_biblia.wv.most_similar("vida")
# Out:
# [('eterna.', 0.8197063207626343),
#  ('vida,', 0.7713834047317505),
#  ('eterna;', 0.7343639135360718),
#  ('eterna', 0.7116934657096863),
#  ('eterna,', 0.7034258842468262),
#  ('creer', 0.6934571266174316),
#  ('vida.', 0.6912249326705933),
#  ('incircuncisión', 0.6911702752113342),
#  ('justificados', 0.6860959529876709),
#  ('cuál', 0.682608962059021)]

# %%
songs2vec_biblia.wv.most_similar("quiero")
# Out:
# [('quisiera', 0.8435990810394287),
#  ('queréis', 0.8229110240936279),
#  ('soportar', 0.8122639656066895),
#  ('quiero,', 0.8078714609146118),
#  ('creéis,', 0.8034185171127319),
#  ('digo.', 0.8012316226959229),
#  ('hago.', 0.8007820844650269),
#  ('aborrezco,', 0.7984345555305481),
#  ('hijitos', 0.7981651425361633),
#  ('queráis', 0.7978537082672119)]

# %%
songs2vec_biblia.wv.most_similar(positive=['dinero'])
# Out:
# [('oficio', 0.7043678760528564),
#  ('rescate', 0.6941173076629639),
#  ('cuenta', 0.6844251155853271),
#  ('melquisedec.', 0.6637261509895325),
#  ('costales,', 0.662918210029602),
#  ('devolverá', 0.6509934067726135),
#  ('recogió', 0.6508060693740845),
#  ('poniéndolo', 0.6486629247665405),
#  ('pueda.', 0.6463227272033691),
#  ('pida', 0.6442655324935913)]

# %%
songs2vec_biblia.wv.most_similar(negative=['dinero'], positive=["te","quiero","vente"])
# Out:
# [('deslealtad,', 0.7425546646118164),
#  ('copa;', 0.7396420836448669),
#  ('saqueado;', 0.7384157180786133),
#  ('mismo?', 0.7368906140327454),
#  ('negaré.', 0.7336001992225647),
#  ('perdonaré.', 0.7290297746658325),
#  ('fueres,', 0.7289489507675171),
#  ('quimam,', 0.7281951904296875),
#  ('olvidaste', 0.727904200553894),
#  ('iré;', 0.7272760272026062)]

# %% [markdown]
# ## Words out of context
# ### CANCIONES

# %%
songs2vec.wv.doesnt_match("felicidad amar gozar odiar".split())
# Out:
# 'felicidad'

# %%
songs2vec.wv.doesnt_match("dinero pasta gozar molar".split())
# Out:
# 'gozar'

# %%
songs2vec.wv.doesnt_match("padre odio terrible rencor".split())
# Out:
# 'terrible'

# %% [markdown]
# ### BIBLIA

# %%
songs2vec_biblia.wv.doesnt_match("felicidad amar gozar odiar".split())
# Out:
# 'amar'

# %%
songs2vec_biblia.wv.doesnt_match("dinero pasta gozar molar".split())
# Out:
# 'gozar'

# %%
songs2vec_biblia.wv.doesnt_match("padre odio terrible rencor".split())
# Out:
# 'padre'

# %% [markdown]
# ### Semantic distance between words

# %%
def nearest_similarity_cosmul_songs(start1, end1, start2):
    similarities = songs2vec.wv.most_similar_cosmul(
        positive=[start2, start1],
        negative=[end1]
    )
    end2 = similarities[0][0]
    print("corpus songs --> {0} es a {1}, lo que {2} es a {3}".format(start1, end1, start2, end2))

def nearest_similarity_cosmul_biblia(start1, end1, start2):
    similarities = songs2vec_biblia.wv.most_similar_cosmul(
        positive=[start2, start1],
        negative=[end1]
    )
    end2 = similarities[0][0]
    print("corpus biblia --> {0} es a {1}, lo que {2} es a {3}".format(start1, end1, start2, end2))

# %%
nearest_similarity_cosmul_songs("amor", "eterno", "odio")
nearest_similarity_cosmul_biblia("amor", "eterno", "odio")
# Out:
# corpus songs --> amor es a eterno, lo que odio es a odio,
# corpus biblia --> amor es a eterno, lo que odio es a azotes,

# %%
nearest_similarity_cosmul_songs("comer", "beber", "hablar")
nearest_similarity_cosmul_biblia("comer", "beber", "hablar")
# Out:
# corpus songs --> comer es a beber, lo que hablar es a hablar,
# corpus biblia --> comer es a beber, lo que hablar es a lengua,

# %%
nearest_similarity_cosmul_songs("dormir", "casa", "comer")
nearest_similarity_cosmul_biblia("dormir", "casa", "comer")
# Out:
# corpus songs --> dormir es a casa, lo que comer es a dormirme
# corpus biblia --> dormir es a casa, lo que comer es a agua,

# %% [markdown]
# #### With the word vector embeddings in place, it is now time to calculate the normalised vector sum of each song. This process can take some time since it has to be done for each of 57,000 songs.

# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def songVector(row):
    vector_sum = 0.0
    words = row.lower().split()
    for word in words:
        vector_sum = vector_sum + songs2vec[word]
    vector_sum = vector_sum.reshape(1,-1)
    normalised_vector_sum = sklearn.preprocessing.normalize(vector_sum)
    return normalised_vector_sum

def bibliaVector(row):
    vector_sum = 0.0
    words = row.lower().split()
    for word in words:
        vector_sum = vector_sum + songs2vec_biblia[word]
    vector_sum = vector_sum.reshape(1,-1)
    normalised_vector_sum = sklearn.preprocessing.normalize(vector_sum)
    return normalised_vector_sum


import time
start_time = time.time()

songs['song_vector'] = songs['letra'].apply(songVector)
# Out:
# ning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# C:\Users\carra\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """

# %%
#biblia_vector =  list(map(bibliaVector, data))

# %% [markdown]
# **t-sne and random song selection**
#
# The songs have 50 dimensions each. Application of t-sne is memory intensive and hence it is slightly easier on the computer to use a random sample of the 57,000 songs.

# %%
song_vectors = []
from sklearn.model_selection import train_test_split

train, test = train_test_split(songs, test_size = 0.9)

for song_vector in train['song_vector']:
    song_vectors.append(song_vector)

train.head(10)
# Out:
#       id             artista                               cancion  \
# 7347   2               Dzano  Lágrimas de niño y corazón de hombre
# 2623  38   Genioh y Cadierno                    Coitos interruptus
# 6807  12             MC Aese                           Beso a beso
# 6434  24  Maikel de la Calle                Or nah (Remix español)
# 374   44          5mentarios     Corazon de banana (con Shinoflow)
# 3914   9           Sondkalle          Raúl Ramírez (con Al Compás)
# 3333  33                Demo       La ciudad de los niños perdidos
# 8634  24               Akrez                          Rosa mistica
# 137   27        Soge Culebra      La pieza del puzzle (con Ambkor)
# 7318  28          Richy Galo                              Tu valor
#
#                                      album  \
# 7347  Lágrimas de niño y corazón de hombre
# 2623                               Punto G
# 6807                              Munchies
# 6434         Sin álbum, es un vídeo suelto
# 374                         Bootleg Vol. 1
# 3914                           Niños robar
# 3333                              Más allá
# 8634          Sin álbum, es un tema suelto
# 137                         Mar de cristal
# 7318                              Decisión
#
#                                                   letra  anyo  visitas  \
# 7347  Si cada derrota es una nueva lección,\nel exam...  2015      468
# 2623  [ Genioh ]\n\n\nEntro y os penetro no quiero a...  2008     2906
# 6807  [Estribillo]\nTu tan bruta yo parlante yo tan ...  2016      767
# 6434  A ella le gusta todo lo que le doy yo\nempezam...  2012    27120
# 374   Vaya noche\ntequeron go,\n5comentario producci...  2009     1707
# 3914  [Estribillo]\nIdentidad,\ncrónicas de una vida...  2006     1829
# 3333  En este mar de maldad mi dedo anular te señala...  2005     2441
# 8634  Entro a mi corazón y de ahí no habrá salida\np...  2013     2678
# 137   [Ambkor]\nSentado en el rellano,\nRayado, pens...  2018     2996
# 7318  [Estribillo]\nValórate de una vez creen ti ten...  2015      401
#
#                                             song_vector
# 7347  [[-0.08757594, 0.094053656, 0.071278654, 0.000...
# 2623  [[-0.042032324, 0.09648913, 0.055291865, 0.028...
# 6807  [[-0.035372846, 0.08116135, 0.088149786, 0.014...
# 6434  [[-0.04307834, 0.082311735, 0.078367114, 0.045...
# 374   [[-0.046998248, 0.054868694, 0.06501387, -0.01...
# 3914  [[-0.041884754, 0.07781396, 0.059423115, 0.014...
# 3333  [[-0.076037705, 0.06355412, 0.058231983, -0.00...
# 8634  [[-0.070330754, 0.09607172, 0.057319473, 0.018...
# 137   [[-0.08005507, 0.08891444, 0.059647404, 0.0217...
# 7318  [[-0.06011723, 0.10457453, 0.07881246, 0.03873...

# %%
#biblia_vectors = []
#from sklearn.model_selection import train_test_split

#train_biblia, test_biblia = train_test_split(data, test_size = 0.9)


#for biblia_vector in train['song_vector']:
#    biblia_vectors.append(biblia_vector)

#train_biblia.head(10)

# %% [markdown]
# I had a fairly measly 4gb machine and wasn't able to generate a more accurate model. However, one can play around with the number of iterations, learning rate and other factors to fit the model better. If you have too many dimensions (~300+), it might make sense to use PCA first and then t-sne.

# %%
X = np.array(song_vectors).reshape((1864, 50))

start_time = time.time()
tsne = sklearn.manifold.TSNE(n_components=2, n_iter=250, random_state=0, verbose=2)

all_word_vectors_matrix_2d = tsne.fit_transform(X)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1864 samples in 0.006s...
# [t-SNE] Computed neighbors for 1864 samples in 0.124s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1864
# [t-SNE] Computed conditional probabilities for sample 1864 / 1864
# [t-SNE] Mean sigma: 0.038290
# [t-SNE] Computed conditional probabilities in 0.063s
# [t-SNE] Iteration 50: error = 70.5571899, gradient norm = 0.1885397 (50 iterations in 0.709s)
# [t-SNE] Iteration 100: error = 69.5248260, gradient norm = 0.1818851 (50 iterations in 0.605s)
# [t-SNE] Iteration 150: error = 70.2356339, gradient norm = 0.1549153 (50 iterations in 0.613s)
# [t-SNE] Iteration 200: error = 70.4157333, gradient norm = 0.1602388 (50 iterations in 0.678s)
# [t-SNE] Iteration 250: error = 69.5551300, gradient norm = 0.1546763 (50 iterations in 0.762s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.555130
# [t-SNE] KL divergence after 251 iterations: .000000
# --- 3.5630548000335693 seconds ---

# %%
df=pd.DataFrame(all_word_vectors_matrix_2d,columns=['X','Y'])

df.head(10)

train.head()

df.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %% [markdown]
# Joining two dataframes to obtain each song's corresponding X,Y co-ordinate.

# %%
two_dimensional_songs = pd.concat([train, df], axis=1)

two_dimensional_songs.head()
# Out:
#      id             artista                               cancion  \
# 0   2.0               Dzano  Lágrimas de niño y corazón de hombre
# 1  38.0   Genioh y Cadierno                    Coitos interruptus
# 2  12.0             MC Aese                           Beso a beso
# 3  24.0  Maikel de la Calle                Or nah (Remix español)
# 4  44.0          5mentarios     Corazon de banana (con Shinoflow)
#
#                                   album  \
# 0  Lágrimas de niño y corazón de hombre
# 1                               Punto G
# 2                              Munchies
# 3         Sin álbum, es un vídeo suelto
# 4                        Bootleg Vol. 1
#
#                                                letra    anyo  visitas  \
# 0  Si cada derrota es una nueva lección,\nel exam...  2015.0    468.0
# 1  [ Genioh ]\n\n\nEntro y os penetro no quiero a...  2008.0   2906.0
# 2  [Estribillo]\nTu tan bruta yo parlante yo tan ...  2016.0    767.0
# 3  A ella le gusta todo lo que le doy yo\nempezam...  2012.0  27120.0
# 4  Vaya noche\ntequeron go,\n5comentario producci...  2009.0   1707.0
#
#                                          song_vector         X         Y
# 0  [[-0.08757594, 0.094053656, 0.071278654, 0.000... -2.227787 -0.053145
# 1  [[-0.042032324, 0.09648913, 0.055291865, 0.028...  2.345802 -0.086516
# 2  [[-0.035372846, 0.08116135, 0.088149786, 0.014... -2.199507  0.073037
# 3  [[-0.04307834, 0.082311735, 0.078367114, 0.045...  2.176128 -0.008516
# 4  [[-0.046998248, 0.054868694, 0.06501387, -0.01... -2.179562 -0.010528

# %% [markdown]
# **Plotting the results**
#
# Using plotly, I plotted the results so that it becomes easier to explore similar songs based on their colors and clusters.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#ma
init_notebook_mode(connected=True)

import plotly.graph_objs as go

trace1 = go.Scatter(
    y = two_dimensional_songs['Y'],
    x = two_dimensional_songs['X'],
    text = two_dimensional_songs['cancion'],
    mode='markers',
    marker=dict(
        size= 10,#'7',
        color = np.random.randn(5717), #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]

iplot(data)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="3694a71f-33d2-469e-a1d8-62a7764bf0ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3694a71f-33d2-469e-a1d8-62a7764bf0ad")) {
#                     Plotly.newPlot(
#                         '3694a71f-33d2-469e-a1d8-62a7764bf0ad',
#                         [{"marker": {"color": [0.3579656768960692, -0.4938821806871155, -1.6405510157919698, 0.23805332486721853, 1.022143710595774, -2.057428363827314, -0.8193717942882573, -0.6187529022739889, -1.005664006839942, -0.4154564200978497, 0.5927232970566872, -0.8224368443184151, 0.24369637172071104, -1.462620683875502, 1.9198919841098467, -0.3789272586740727, 1.1823790082112766, -0.9853298840215122, 0.8975795814297324, 0.6175367791816742, 0.551432395265449, 1.0466421465964912, -0.28921605795152583, 0.8007225801019385, -0.03511113541595269, -1.4437655234402176, -0.3341948304028489, -0.3842847071393985, -2.5267249742321245, -0.505497399738869, 0.26932104771529725, 1.1294916889313515, 1.0417387461535896, 1.1160062763828549, 1.8522099406310202, -1.098767144455536, 0.8077685440306185, -0.1661844432791201, -1.0343610844515119, 2.1168055701009836, -1.480296917653527, 0.13734575219833606, 0.15511305381190005, -0.9946543639022922, -0.46048460885071657, -0.6569408176045497, 0.41436959078943403, -0.09685486064477894, -0.33520452048031685, -0.31288215960650373, 1.093310233342352, 0.9696696746301838, 0.6382403638559564, 0.9056772840824286, 0.892591918019392, -0.6305263009640701, -0.37112399097380977, 1.4665895949083818, -0.6113743446357782, -0.01629698633003586, 0.6966885826250375, -0.6899819526094466, -0.8395237211107339, 0.47846176755644126, 1.4113673997621614, 0.1484548309594531, 1.2971699494589208, -1.8870427995593115, -0.893070715366195, -2.595975544444865, -1.2613685491596947, -0.8470760431282163, -1.1101113354740206, -0.21989348867441166, 0.4260413558946471, -0.7165777981086736, 0.48133433706056616, 0.037616524078563446, 0.31077555668501644, 1.2120381733286647, -1.1957150867545834, -0.3719399262060626, -0.8602071129133256, -1.7307480913787283, -0.9978837845799576, -0.0735021656444266, -1.43578791620203, -1.0962967543144322, 2.122909373386113, 0.47485031503583136, -0.05077415424808056, -0.38570488853269175, -1.7048386824567334, -1.2143501637621525, 0.4814617236479025, 0.79740974828696, 0.381191687720288, -0.7047633229541914, -0.302689650197612, -0.8971956594545359, -1.8369264608654452, -1.647723285781722, -0.5748357897068012, 0.7686332575023742, -0.6200416694530095, 0.5749572728453393, -1.116787314285698, -0.7897975172212846, 0.7940132585893136, 0.5871475360591767, -0.08238129958471886, -0.8097158926380791, -0.5216891457947815, -0.44739827228060597, 0.9087462795142642, -0.013704641959307557, -0.30170223242013233, -0.08234462156838304, 2.6195002096902735, -0.04513666237017635, 0.9616364919422453, 0.5472458943688135, -0.07495957356482594, -1.2678972856830752, 0.1551518175045639, -0.9302953518626523, -1.7885178046943513, 1.4692847332536367, -0.049440084042227814, 1.1389711396066617, -0.4725205418388541, -0.4056280907887271, -0.32294364059904185, -0.10903591797701548, 1.044018604803702, 1.2215013758802804, -0.0844831168330005, 1.1228925817010345, -1.3942756256048474, 0.9413513566115167, 0.004164276892430879, -1.2786062843089279, 0.7144154887257547, 1.4771577525591648, -1.2523865721531737, 0.05968613639353718, 0.6142766939839773, -1.0075879645616623, -3.0210971554666037, 1.0383638818984124, 0.15124841646573492, -0.7756969286516724, 0.34258268918454854, 1.702704854599081, 0.3136250620157562, 0.903866912114947, -0.8327692539101822, -0.47158064038195846, 0.666837449090894, 0.7246865341296572, -1.5997313558152513, -1.7914056301683752, 1.9573428374262265, 0.6121273149499682, 0.21996974698816363, -0.2311920343322196, -0.3181276449226501, -0.7071607212670674, 1.4711170137640932, -2.6666587162994366, -0.5698651816900294, 1.3044930983213734, 0.6314775338215378, 0.8893924408549319, -0.1540176767714182, 1.236973186071034, -0.6971885330475373, -1.9659297248387428, 0.8965905250181408, -1.0442172611090847, 1.1141565936650124, 0.6153460093082251, 2.659411521279655, 0.6129646180964717, 0.3541707314250173, -0.9574177590975979, -1.8652116873076412, -0.6924100006909395, -0.9197892022043898, -0.6406693665439366, -1.3022071570947529, -0.259478420 ...

# %% [markdown]
# LA SIGUIENTE TIENE SENTIDO, SON ARTISTAS DE RAP POR LO QUE ESTA HACIENDO BIEN EL MODELO, EL CHOJIN, XHELAZ, R DE RUMBA, EL HINCHU

# %%
import plotly.graph_objects as go
import numpy as np

fig = go.Figure(data=go.Scatter(
    y = two_dimensional_songs['Y'],
    x = two_dimensional_songs['X'],
    text = two_dimensional_songs['artista']+ "_"+two_dimensional_songs['cancion'] ,
    mode='markers',
    marker=dict(
        size= 10,#'7',
        color = np.random.randn(5717), #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
))

fig.show()
# Out:
# <div>
#
#
#             <div id="aadb7809-bd28-4294-9fb9-9d5393e2bea9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aadb7809-bd28-4294-9fb9-9d5393e2bea9")) {
#                     Plotly.newPlot(
#                         'aadb7809-bd28-4294-9fb9-9d5393e2bea9',
#                         [{"marker": {"color": [-0.022968698801326577, -1.4958420846702023, 0.044693899894292476, 0.867880285618444, 1.0163166703442357, 1.03254842989079, -1.7272911861911762, 0.23586678885904813, 0.5394943064402932, -0.42871941089706245, -0.7570112590261264, -1.6010868253236084, 0.4027140563775678, 0.3229928226119848, -1.0118579242279155, -1.50366355761022, -0.5207964444132543, -0.5773125927520447, 1.0081837459892629, -0.7292958578423036, -0.014276187320549843, 0.2739424814757282, -1.1416510051886097, -0.144517685374541, -2.004979643126767, -1.1578761738935224, -2.319888915152635, 0.3208450377707197, -0.7575284129085754, -0.6399831206109458, 0.